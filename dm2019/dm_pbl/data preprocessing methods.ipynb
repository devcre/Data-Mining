# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
mort = pd.read_csv('./data.csv', header=0) # data about mortgage
tmort = mort.T

mort
# Out:
#        Bo_Age   Ln_Orig  Orig_LTV_Ratio_Pct  Credit_score First_home  \
# 0          37   75650.0                  85           669          N
# 1          46  390775.0                 102           684          N
# 2          30  112500.0                  90           662          Y
# 3          24   85250.0                  97           647          N
# 4          35  114000.0                 100           791          N
# ...       ...       ...                 ...           ...        ...
# 10602      37  280200.0                  95           652          Y
# 10603      30   57000.0                  94           589          N
# 10604      33  153200.0                  95           675          Y
# 10605      38  158850.0                 100           786          Y
# 10606      37   47000.0                  89           683          Y
#
#        Tot_mthly_debt_exp  Tot_mthly_incm  orig_apprd_val_amt  pur_prc_amt  \
# ...

# %%
tmort
# Out:
#                           0            1            2            3      \
# Bo_Age                       37           46           30           24
# Ln_Orig                   75650       390775       112500        85250
# Orig_LTV_Ratio_Pct           85          102           90           97
# Credit_score                669          684          662          647
# First_home                    N            N            Y            N
# Tot_mthly_debt_exp         1707            0         1812         3395
# Tot_mthly_incm             6000         5025         4800         6934
# orig_apprd_val_amt       169000       310000       177000       113000
# pur_prc_amt              160000       309000       176450       110000
# DTI Ratio                0.2845            0       0.3775     0.489616
# Status                   Active      Pay-off      Pay-off      Pay-off
# OUTCOME             non-default  non-default  non-default  non-default
# ...

# %%
# 딕셔너리 형태로 정의하는 데이터 타입. 자주 활용되는 데이터 타입은 아님 
type(mort)
# Out:
# pandas.core.frame.DataFrame

# %%
# 행(row)과 열(column)의 개수
mort.shape
# Out:
# (10607, 15)

# %%
mort.keys()
# Out:
# Index(['Bo_Age', 'Ln_Orig', 'Orig_LTV_Ratio_Pct', 'Credit_score', 'First_home',
#        'Tot_mthly_debt_exp', 'Tot_mthly_incm', 'orig_apprd_val_amt',
#        'pur_prc_amt', 'DTI Ratio', 'Status', 'OUTCOME', 'State',
#        'Median_state_inc', 'UPB>Appraisal'],
#       dtype='object')

# %%
print(mort['Ln_Orig'])
# Out:
# 0         75650.0
# 1        390775.0
# 2        112500.0
# 3         85250.0
# 4        114000.0
# 5        207200.0
# 6        193000.0
# 7        220500.0
# 8         79800.0
# 9        109100.0
# 10       179000.0
# 11       116850.0
# 12       257000.0
# 13       223200.0
# 14       184000.0
# 15       260000.0
# 16       260775.0
# 17       209800.0
# 18       139900.0
# 19       319623.0
# 20        90630.0
# 21       256500.0
# 22        99500.0
# 23       204900.0
# 24        66930.0
# 25        68400.0
# 26       141450.0
# 27       148700.0
# 28       107590.0
# 29       141744.0
#            ...
# 10577     77400.0
# 10578    149625.0
# 10579    104465.0
# 10580    219000.0
# 10581    113353.0
# 10582     77600.0
# 10583    156000.0
# 10584    260100.0
# 10585    144000.0
# 10586    102500.0
# 10587     67000.0
# 10588     85500.0
# 10589    182400.0
# 10590    295000.0
# 10591    120000.0
# 10592     91000.0
# 10593     76400.0
# 10594    139550.0
# 10595     80000.0
# ...

# %%
# mort.Bo_Age 와 같은 의미
pd.DataFrame(mort, columns=['Bo_Age'])
# Out:
#        Bo_Age
# 0          37
# 1          46
# 2          30
# 3          24
# 4          35
# 5          38
# 6          26
# 7          39
# 8          41
# 9          22
# 10         32
# 11         21
# 12         31
# 13         34
# 14         37
# 15         37
# 16         63
# 17         37
# 18         41
# 19         35
# 20         37
# 21         30
# 22         29
# 23         23
# 24         24
# 25         39
# 26         25
# 27         30
# 28         27
# 29         78
# ...       ...
# 10577      55
# 10578      25
# 10579      37
# 10580      37
# 10581      33
# 10582      24
# 10583      48
# 10584      31
# 10585      37
# 10586      70
# 10587      26
# 10588      37
# 10589      29
# 10590      37
# 10591      37
# 10592      37
# 10593      41
# 10594      24
# 10595      37
# 10596      39
# 10597      33
# 10598      37
# 10599      30
# 10600      35
# 10601      37
# 10602      37
# 10603      30
# 10604      33
# 10605      38
# 10606      37
#
# ...

# %%
# 10 행에 해당하는 데이터를 전체 열로 출력
mort.loc[10,:]
# Out:
# Bo_Age                         32
# Ln_Orig                    179000
# Orig_LTV_Ratio_Pct            100
# Credit_score                  686
# First_home                      Y
# Tot_mthly_debt_exp           3464
# Tot_mthly_incm               5025
# orig_apprd_val_amt         310000
# pur_prc_amt                300500
# DTI Ratio                0.689397
# Status                     Active
# OUTCOME               non-default
# State                          NY
# Median_state_inc           44,228
# UPB>Appraisal                   0
# Name: 10, dtype: object

# %%
print('Status', np.unique(mort['Status']))
mort.head()
# Out:
# Status ['Active' 'Default' 'Pay-off']
#    Bo_Age   Ln_Orig  Orig_LTV_Ratio_Pct  Credit_score First_home  \
# 0      37   75650.0                  85           669          N
# 1      46  390775.0                 102           684          N
# 2      30  112500.0                  90           662          Y
# 3      24   85250.0                  97           647          N
# 4      35  114000.0                 100           791          N
#
#    Tot_mthly_debt_exp  Tot_mthly_incm  orig_apprd_val_amt  pur_prc_amt  \
# 0                1707            6000              169000       160000
# 1                   0            5025              310000       309000
# 2                1812            4800              177000       176450
# 3                3395            6934              113000       110000
# 4                3801            5504              103000       103000
#
#    DTI Ratio   Status      OUTCOME State Median_state_inc  UPB>Appraisal
# ...

# %%
print('OUTCOME', np.unique(mort['OUTCOME']))
mort.head()
# Out:
# OUTCOME ['default' 'non-default']
#    Bo_Age   Ln_Orig  Orig_LTV_Ratio_Pct  Credit_score First_home  \
# 0      37   75650.0                  85           669          N
# 1      46  390775.0                 102           684          N
# 2      30  112500.0                  90           662          Y
# 3      24   85250.0                  97           647          N
# 4      35  114000.0                 100           791          N
#
#    Tot_mthly_debt_exp  Tot_mthly_incm  orig_apprd_val_amt  pur_prc_amt  \
# 0                1707            6000              169000       160000
# 1                   0            5025              310000       309000
# 2                1812            4800              177000       176450
# 3                3395            6934              113000       110000
# 4                3801            5504              103000       103000
#
#    DTI Ratio   Status      OUTCOME State Median_state_inc  UPB>Appraisal
# ...

# %%
print('State', np.unique(mort['State']))
# Out:
# State ['AK' 'AL' 'AR' 'AZ' 'CA' 'CO' 'CT' 'DC' 'DE' 'FL' 'GA' 'HI' 'IA' 'ID'
#  'IL' 'IN' 'KS' 'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC'
#  'ND' 'NE' 'NH' 'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'RI' 'SC' 'SD'
#  'TN' 'TX' 'UT' 'VA' 'VT' 'WA' 'WI' 'WV' 'WY']
